# %%
# Updating sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
import pandas as pd
import numpy as np

# %%
# Reading CSV
df = pd.read_csv("source_data/exoplanet_data.csv")
# Dropping the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Dropping the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features/x values
selected_features = df.drop("koi_disposition", axis=1)

# %%
# Setting y value
y = df["koi_disposition"]
print(selected_features.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Creating test/train split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=21)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6966              1              0              1              0  361.901618
# 1714              0              0              0              0    6.739683
# 225               0              0              0              0    3.166354
# 5266              0              0              0              0   25.090157
# 5468              0              1              0              0    7.234966
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6966         0.008898        -0.008898   405.302100          0.020000
# 1714         0.000064        -0.000064   132.292960          0.008160
# 225          0.000003        -0.000003   170.966145          0.000631
# 5266         0.000482        -0.000482   138.498800          0.016200
# 5468         0.000002        -0.000002   134.582307          0.000207
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6966         -0.020000  ...            -136      4.603           0.040
# 1714         -0.008160  ...             -71      4.261           0.168
# 225          -0.000631  ...            -211      4.470           0.052
# 5266         -0.016200  ...            -183      3.985           0.266
# 5468         -0.000207  ...            -186      4.573           0.040
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6966          -0.060     0.717          0.086         -0.058  290.37891
# 1714          -0.112     1.176          0.183         -0.203  280.82339
# 225           -0.208     0.998          0.318         -0.106  286.36011
# 5266          -0.114     1.788          0.351         -0.571  298.67377
# 5468          -0.160     0.798          0.206         -0.069  290.22617
#
#             dec  koi_kepmag
# 6966  39.694000      12.673
# 1714  42.636051      14.455
# 225   45.414291      15.603
# 5266  43.795479      12.014
# 5468  37.759640      16.981
#
# [5 rows x 40 columns]

# %%
# Scaling the data
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Label encoding
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# One-hot encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
# Training the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fitting the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.8587 - accuracy: 0.5600
# Epoch 2/100
# 164/164 - 0s - loss: 0.6003 - accuracy: 0.7818
# Epoch 3/100
# 164/164 - 0s - loss: 0.4216 - accuracy: 0.8259
# Epoch 4/100
# 164/164 - 0s - loss: 0.3473 - accuracy: 0.8449
# Epoch 5/100
# 164/164 - 0s - loss: 0.3146 - accuracy: 0.8606
# Epoch 6/100
# 164/164 - 0s - loss: 0.2968 - accuracy: 0.8714
# Epoch 7/100
# 164/164 - 0s - loss: 0.2823 - accuracy: 0.8796
# Epoch 8/100
# 164/164 - 0s - loss: 0.2764 - accuracy: 0.8810
# Epoch 9/100
# 164/164 - 0s - loss: 0.2700 - accuracy: 0.8817
# Epoch 10/100
# 164/164 - 0s - loss: 0.2652 - accuracy: 0.8871
# Epoch 11/100
# 164/164 - 0s - loss: 0.2620 - accuracy: 0.8875
# Epoch 12/100
# 164/164 - 0s - loss: 0.2588 - accuracy: 0.8886
# Epoch 13/100
# 164/164 - 0s - loss: 0.2544 - accuracy: 0.8909
# Epoch 14/100
# 164/164 - 0s - loss: 0.2522 - accuracy: 0.8938
# Epoch 15/100
# 164/164 - 0s - loss: 0.2511 - accuracy: 0.8957
# Epoch 16/100
# 164/164 - 0s - loss: 0.2479 - accuracy: 0.8955
# Epoch 17/100
# 164/164 - 0s - loss: 0.2465 - accuracy: 0.8945
# Epoch 18/100
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8938
# Epoch 19/100
# 164/164 - 0s - loss: 0.2433 - accuracy: 0.8943
# Epoch 20/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8974
# Epoch 21/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8957
# Epoch 22/100
# 164/164 - 0s - loss: 0.2387 - accuracy: 0.8991
# Epoch 23/100
# 164/164 - 0s - loss: 0.2370 - accuracy: 0.8978
# Epoch 24/100
# 164/164 - 0s - loss: 0.2354 - accuracy: 0.8985
# Epoch 25/100
# 164/164 - 0s - loss: 0.2358 - accuracy: 0.8987
# Epoch 26/100
# 164/164 - 0s - loss: 0.2330 - accuracy: 0.9001
# Epoch 27/100
# 164/164 - 0s - loss: 0.2319 - accuracy: 0.9018
# Epoch 28/100
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.8993
# Epoch 29/100
# 164/164 - 0s - loss: 0.2287 - accuracy: 0.9001
# Epoch 30/100
# 164/164 - 0s - loss: 0.2284 - accuracy: 0.9002
# Epoch 31/100
# 164/164 - 0s - loss: 0.2269 - accuracy: 0.9020
# Epoch 32/100
# 164/164 - 0s - loss: 0.2255 - accuracy: 0.9035
# Epoch 33/100
# 164/164 - 0s - loss: 0.2244 - accuracy: 0.9022
# Epoch 34/100
# 164/164 - 0s - loss: 0.2237 - accuracy: 0.9046
# Epoch 35/100
# 164/164 - 0s - loss: 0.2220 - accuracy: 0.9054
# Epoch 36/100
# 164/164 - 0s - loss: 0.2210 - accuracy: 0.9046
# Epoch 37/100
# 164/164 - 0s - loss: 0.2215 - accuracy: 0.9056
# Epoch 38/100
# 164/164 - 0s - loss: 0.2194 - accuracy: 0.9054
# Epoch 39/100
# 164/164 - 0s - loss: 0.2186 - accuracy: 0.9060
# Epoch 40/100
# 164/164 - 0s - loss: 0.2180 - accuracy: 0.9048
# Epoch 41/100
# 164/164 - 0s - loss: 0.2181 - accuracy: 0.9054
# Epoch 42/100
# 164/164 - 0s - loss: 0.2174 - accuracy: 0.9079
# Epoch 43/100
# 164/164 - 0s - loss: 0.2171 - accuracy: 0.9065
# Epoch 44/100
# 164/164 - 0s - loss: 0.2155 - accuracy: 0.9081
# Epoch 45/100
# 164/164 - 0s - loss: 0.2149 - accuracy: 0.9084
# Epoch 46/100
# 164/164 - 0s - loss: 0.2149 - accuracy: 0.9073
# Epoch 47/100
# 164/164 - 0s - loss: 0.2125 - accuracy: 0.9105
# Epoch 48/100
# 164/164 - 0s - loss: 0.2130 - accuracy: 0.9088
# Epoch 49/100
# 164/164 - 0s - loss: 0.2116 - accuracy: 0.9104
# Epoch 50/100
# 164/164 - 0s - loss: 0.2115 - accuracy: 0.9092
# Epoch 51/100
# 164/164 - 0s - loss: 0.2102 - accuracy: 0.9096
# Epoch 52/100
# 164/164 - 0s - loss: 0.2096 - accuracy: 0.9107
# Epoch 53/100
# 164/164 - 0s - loss: 0.2099 - accuracy: 0.9115
# Epoch 54/100
# 164/164 - 0s - loss: 0.2081 - accuracy: 0.9117
# Epoch 55/100
# 164/164 - 0s - loss: 0.2085 - accuracy: 0.9111
# Epoch 56/100
# 164/164 - 0s - loss: 0.2063 - accuracy: 0.9123
# Epoch 57/100
# 164/164 - 0s - loss: 0.2082 - accuracy: 0.9109
# Epoch 58/100
# 164/164 - 0s - loss: 0.2076 - accuracy: 0.9138
# Epoch 59/100
# 164/164 - 0s - loss: 0.2057 - accuracy: 0.9126
# Epoch 60/100
# 164/164 - 0s - loss: 0.2064 - accuracy: 0.9113
# Epoch 61/100
# 164/164 - 0s - loss: 0.2061 - accuracy: 0.9126
# Epoch 62/100
# 164/164 - 0s - loss: 0.2051 - accuracy: 0.9153
# Epoch 63/100
# 164/164 - 0s - loss: 0.2046 - accuracy: 0.9138
# Epoch 64/100
# 164/164 - 0s - loss: 0.2039 - accuracy: 0.9132
# Epoch 65/100
# 164/164 - 0s - loss: 0.2037 - accuracy: 0.9144
# Epoch 66/100
# 164/164 - 0s - loss: 0.2032 - accuracy: 0.9146
# Epoch 67/100
# 164/164 - 0s - loss: 0.2025 - accuracy: 0.9151
# Epoch 68/100
# 164/164 - 0s - loss: 0.2031 - accuracy: 0.9138
# Epoch 69/100
# 164/164 - 0s - loss: 0.2024 - accuracy: 0.9146
# Epoch 70/100
# 164/164 - 0s - loss: 0.2020 - accuracy: 0.9140
# Epoch 71/100
# 164/164 - 0s - loss: 0.2011 - accuracy: 0.9140
# Epoch 72/100
# 164/164 - 0s - loss: 0.2007 - accuracy: 0.9147
# Epoch 73/100
# 164/164 - 0s - loss: 0.2021 - accuracy: 0.9117
# Epoch 74/100
# 164/164 - 0s - loss: 0.2002 - accuracy: 0.9170
# Epoch 75/100
# 164/164 - 0s - loss: 0.2005 - accuracy: 0.9136
# Epoch 76/100
# 164/164 - 0s - loss: 0.1991 - accuracy: 0.9153
# Epoch 77/100
# 164/164 - 0s - loss: 0.1993 - accuracy: 0.9168
# Epoch 78/100
# 164/164 - 0s - loss: 0.2004 - accuracy: 0.9134
# Epoch 79/100
# 164/164 - 0s - loss: 0.1979 - accuracy: 0.9165
# Epoch 80/100
# 164/164 - 0s - loss: 0.1978 - accuracy: 0.9176
# Epoch 81/100
# 164/164 - 0s - loss: 0.1987 - accuracy: 0.9191
# Epoch 82/100
# 164/164 - 0s - loss: 0.1981 - accuracy: 0.9186
# Epoch 83/100
# 164/164 - 0s - loss: 0.1979 - accuracy: 0.9168
# Epoch 84/100
# 164/164 - 0s - loss: 0.1967 - accuracy: 0.9174
# Epoch 85/100
# 164/164 - 0s - loss: 0.1979 - accuracy: 0.9167
# Epoch 86/100
# 164/164 - 0s - loss: 0.1979 - accuracy: 0.9178
# Epoch 87/100
# 164/164 - 0s - loss: 0.1967 - accuracy: 0.9146
# Epoch 88/100
# 164/164 - 0s - loss: 0.1962 - accuracy: 0.9153
# Epoch 89/100
# 164/164 - 0s - loss: 0.1968 - accuracy: 0.9149
# Epoch 90/100
# 164/164 - 0s - loss: 0.1957 - accuracy: 0.9178
# Epoch 91/100
# 164/164 - 0s - loss: 0.1958 - accuracy: 0.9167
# Epoch 92/100
# 164/164 - 0s - loss: 0.1956 - accuracy: 0.9172
# Epoch 93/100
# 164/164 - 0s - loss: 0.1946 - accuracy: 0.9170
# Epoch 94/100
# 164/164 - 0s - loss: 0.1949 - accuracy: 0.9174
# Epoch 95/100
# 164/164 - 0s - loss: 0.1947 - accuracy: 0.9151
# Epoch 96/100
# 164/164 - 0s - loss: 0.1946 - accuracy: 0.9159
# Epoch 97/100
# 164/164 - 0s - loss: 0.1942 - accuracy: 0.9167
# Epoch 98/100
# 164/164 - 0s - loss: 0.1940 - accuracy: 0.9159
# Epoch 99/100
# 164/164 - 0s - loss: 0.1940 - accuracy: 0.9140
# Epoch 100/100
# 164/164 - 0s - loss: 0.1927 - accuracy: 0.9208

# %%
# Evaluating the model
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3107 - accuracy: 0.8919
# Deep Neural Network - Loss: 0.31074362993240356, Accuracy: 0.8918764591217041

# %%
# Making inferences
encoded_predictions = np.argmax(model.predict(X_test_scaled[:10]), axis=-1)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
inference_df = pd.DataFrame({'Predicted': prediction_labels, 'Actual': (y_test[:10])}).sort_index()
inference_df
# Out:
#            Predicted          Actual
# 1039       CONFIRMED       CONFIRMED
# 2046       CANDIDATE       CONFIRMED
# 2693       CANDIDATE       CANDIDATE
# 3481  FALSE POSITIVE  FALSE POSITIVE
# 4104  FALSE POSITIVE  FALSE POSITIVE
# 4252  FALSE POSITIVE  FALSE POSITIVE
# 4496  FALSE POSITIVE  FALSE POSITIVE
# 4945       CANDIDATE       CANDIDATE
# 5819  FALSE POSITIVE  FALSE POSITIVE
# 6378  FALSE POSITIVE  FALSE POSITIVE

# %%
# Saving the model
model.save("deep_learning_model.h5")
