# %%
# Updating sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# Installing joblib
# !pip install joblib

# %%
import pandas as pd

# %%
# Reading CSV
df = pd.read_csv("source_data/exoplanet_data.csv")
# Dropping the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Dropping the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features/x values
selected_features = df.drop("koi_disposition", axis=1)

# %%
# Setting y value
y = df["koi_disposition"]
print(selected_features.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Creating test/train split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=21)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6966              1              0              1              0  361.901618
# 1714              0              0              0              0    6.739683
# 225               0              0              0              0    3.166354
# 5266              0              0              0              0   25.090157
# 5468              0              1              0              0    7.234966
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6966         0.008898        -0.008898   405.302100          0.020000
# 1714         0.000064        -0.000064   132.292960          0.008160
# 225          0.000003        -0.000003   170.966145          0.000631
# 5266         0.000482        -0.000482   138.498800          0.016200
# 5468         0.000002        -0.000002   134.582307          0.000207
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6966         -0.020000  ...            -136      4.603           0.040
# 1714         -0.008160  ...             -71      4.261           0.168
# 225          -0.000631  ...            -211      4.470           0.052
# 5266         -0.016200  ...            -183      3.985           0.266
# 5468         -0.000207  ...            -186      4.573           0.040
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6966          -0.060     0.717          0.086         -0.058  290.37891
# 1714          -0.112     1.176          0.183         -0.203  280.82339
# 225           -0.208     0.998          0.318         -0.106  286.36011
# 5266          -0.114     1.788          0.351         -0.571  298.67377
# 5468          -0.160     0.798          0.206         -0.069  290.22617
#
#             dec  koi_kepmag
# 6966  39.694000      12.673
# 1714  42.636051      14.455
# 225   45.414291      15.603
# 5266  43.795479      12.014
# 5468  37.759640      16.981
#
# [5 rows x 40 columns]

# %%
# Scaling the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Training the model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=200)
model.fit(X_train_scaled, y_train)

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8832951945080092

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.10024405, 0.06912427, 0.10895143, 0.03391889, 0.02222167,
#        0.01964898, 0.01861658, 0.0133119 , 0.02230137, 0.02120567,
#        0.02016448, 0.01108689, 0.0101998 , 0.02370824, 0.03231444,
#        0.03557253, 0.02092239, 0.01380853, 0.01428526, 0.04929524,
#        0.03078548, 0.03025581, 0.01648772, 0.01361671, 0.01734265,
#        0.01117992, 0.0612531 , 0.00322881, 0.00932537, 0.03003395,
#        0.02506854, 0.00914312, 0.008394  , 0.01028688, 0.00926525,
#        0.01126508, 0.00871171, 0.01173911, 0.01126848, 0.01044569])

# %%
feature_names = selected_features.columns
sorted(zip(model.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10895143194717612, 'koi_fpflag_co'),
#  (0.10024404874357488, 'koi_fpflag_nt'),
#  (0.06912427047482474, 'koi_fpflag_ss'),
#  (0.061253095522498836, 'koi_model_snr'),
#  (0.04929524189279832, 'koi_prad'),
#  (0.03557252803301809, 'koi_duration_err2'),
#  (0.03391889479710922, 'koi_fpflag_ec'),
#  (0.03231444145757325, 'koi_duration_err1'),
#  (0.03078547534052932, 'koi_prad_err1'),
#  (0.03025580800793375, 'koi_prad_err2'),
#  (0.030033951037824393, 'koi_steff_err1'),
#  (0.025068543041762096, 'koi_steff_err2'),
#  (0.02370824019756247, 'koi_duration'),
#  (0.022301373189958014, 'koi_time0bk_err1'),
#  (0.022221670939614392, 'koi_period'),
#  (0.021205669421756695, 'koi_time0bk_err2'),
#  (0.02092239403697677, 'koi_depth'),
#  (0.020164475126395104, 'koi_impact'),
#  (0.019648978972360665, 'koi_period_err1'),
#  (0.018616583871767466, 'koi_period_err2'),
#  (0.017342652349395183, 'koi_insol_err1'),
#  (0.016487721545092596, 'koi_teq'),
#  (0.014285261013565307, 'koi_depth_err2'),
#  (0.01380852960822885, 'koi_depth_err1'),
#  (0.013616713729950969, 'koi_insol'),
#  (0.013311902898973507, 'koi_time0bk'),
#  (0.011739106710631211, 'ra'),
#  (0.011268481176929888, 'dec'),
#  (0.011265075667361665, 'koi_srad_err1'),
#  (0.011179919940197243, 'koi_insol_err2'),
#  (0.0110868905915472, 'koi_impact_err1'),
#  (0.010445688801250247, 'koi_kepmag'),
#  (0.010286875015830012, 'koi_slogg_err2'),
#  (0.010199803073478543, 'koi_impact_err2'),
#  (0.009325369758094228, 'koi_steff'),
#  (0.009265253747504663, 'koi_srad'),
#  (0.00914311780525037, 'koi_slogg'),
#  (0.008711707168581918, 'koi_srad_err2'),
#  (0.008394000274802173, 'koi_slogg_err1'),
#  (0.003228813070319577, 'koi_tce_plnt_num')]

# %%
# Re-setting significant features/x values
sig_features = df.drop(["koi_disposition", "koi_tce_plnt_num", "koi_slogg", "koi_srad_err2", "koi_slogg_err1", "koi_steff", "koi_slogg_err2", "koi_srad"], axis=1)

# %%
X_train2, X_test2, y_train, y_test = train_test_split(sig_features, y, random_state=21)
X_train2.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6966              1              0              1              0  361.901618
# 1714              0              0              0              0    6.739683
# 225               0              0              0              0    3.166354
# 5266              0              0              0              0   25.090157
# 5468              0              1              0              0    7.234966
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6966         0.008898        -0.008898   405.302100          0.020000
# 1714         0.000064        -0.000064   132.292960          0.008160
# 225          0.000003        -0.000003   170.966145          0.000631
# 5266         0.000482        -0.000482   138.498800          0.016200
# 5468         0.000002        -0.000002   134.582307          0.000207
#
#       koi_time0bk_err2  ...  koi_insol  koi_insol_err1  koi_insol_err2  \
# 6966         -0.020000  ...       0.37            0.14           -0.09
# 1714         -0.008160  ...     246.90          102.89          -86.42
# 225          -0.000631  ...     621.92          586.40         -191.31
# 5266         -0.016200  ...     124.33           76.20          -73.41
# 5468         -0.000207  ...     119.12           95.50          -32.16
#
#       koi_model_snr  koi_steff_err1  koi_steff_err2  koi_srad_err1         ra  \
# 6966            8.5             136            -136          0.086  290.37891
# 1714           15.4              82             -71          0.183  280.82339
# 225           128.3             169            -211          0.318  286.36011
# 5266           12.1             183            -183          0.351  298.67377
# 5468          671.3             186            -186          0.206  290.22617
#
#             dec  koi_kepmag
# 6966  39.694000      12.673
# 1714  42.636051      14.455
# 225   45.414291      15.603
# 5266  43.795479      12.014
# 5468  37.759640      16.981
#
# [5 rows x 33 columns]

# %%
# Scaling the data
X_scaler2 = MinMaxScaler().fit(X_train2)
X_train_scaled2 = X_scaler2.transform(X_train2)
X_test_scaled2 = X_scaler2.transform(X_test2)

# %%
# Training the model on the significant features
model.fit(X_train_scaled2, y_train)

print(f"Training Data Score: {model.score(X_train_scaled2, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled2, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8850114416475973

# %%
# Creating the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'max_depth': [5, 10, 20], 'min_samples_split': [5, 10, 20]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# RandomForestClassifier().get_params().keys()

# %%
# Training the model with GridSearch
grid.fit(X_train_scaled2, y_train);
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ..max_depth=5, min_samples_split=5;, score=0.848 total time=   0.9s
# [CV 2/5] END ..max_depth=5, min_samples_split=5;, score=0.843 total time=   0.9s
# [CV 3/5] END ..max_depth=5, min_samples_split=5;, score=0.866 total time=   0.9s
# [CV 4/5] END ..max_depth=5, min_samples_split=5;, score=0.889 total time=   1.0s
# [CV 5/5] END ..max_depth=5, min_samples_split=5;, score=0.870 total time=   0.9s
# [CV 1/5] END .max_depth=5, min_samples_split=10;, score=0.845 total time=   0.9s
# [CV 2/5] END .max_depth=5, min_samples_split=10;, score=0.844 total time=   0.9s
# [CV 3/5] END .max_depth=5, min_samples_split=10;, score=0.877 total time=   1.0s
# [CV 4/5] END .max_depth=5, min_samples_split=10;, score=0.887 total time=   0.9s
# [CV 5/5] END .max_depth=5, min_samples_split=10;, score=0.873 total time=   0.9s
# [CV 1/5] END .max_depth=5, min_samples_split=20;, score=0.844 total time=   0.9s
# [CV 2/5] END .max_depth=5, min_samples_split=20;, score=0.848 total time=   0.9s
# [CV 3/5] END .max_depth=5, min_samples_split=20;, score=0.877 total time=   0.9s
# [CV 4/5] END .max_depth=5, min_samples_split=20;, score=0.887 total time=   0.9s
# [CV 5/5] END .max_depth=5, min_samples_split=20;, score=0.868 total time=   0.9s
# [CV 1/5] END .max_depth=10, min_samples_split=5;, score=0.891 total time=   1.4s
# [CV 2/5] END .max_depth=10, min_samples_split=5;, score=0.877 total time=   1.4s
# [CV 3/5] END .max_depth=10, min_samples_split=5;, score=0.895 total time=   1.4s
# [CV 4/5] END .max_depth=10, min_samples_split=5;, score=0.913 total time=   1.4s
# [CV 5/5] END .max_depth=10, min_samples_split=5;, score=0.888 total time=   1.4s
# [CV 1/5] END max_depth=10, min_samples_split=10;, score=0.886 total time=   1.4s
# [CV 2/5] END max_depth=10, min_samples_split=10;, score=0.874 total time=   1.4s
# [CV 3/5] END max_depth=10, min_samples_split=10;, score=0.895 total time=   1.4s
# [CV 4/5] END max_depth=10, min_samples_split=10;, score=0.908 total time=   1.4s
# [CV 5/5] END max_depth=10, min_samples_split=10;, score=0.890 total time=   1.4s
# [CV 1/5] END max_depth=10, min_samples_split=20;, score=0.881 total time=   1.5s
# [CV 2/5] END max_depth=10, min_samples_split=20;, score=0.876 total time=   1.5s
# [CV 3/5] END max_depth=10, min_samples_split=20;, score=0.900 total time=   1.5s
# [CV 4/5] END max_depth=10, min_samples_split=20;, score=0.911 total time=   1.5s
# [CV 5/5] END max_depth=10, min_samples_split=20;, score=0.887 total time=   1.4s
# [CV 1/5] END .max_depth=20, min_samples_split=5;, score=0.888 total time=   1.7s
# [CV 2/5] END .max_depth=20, min_samples_split=5;, score=0.880 total time=   1.7s
# [CV 3/5] END .max_depth=20, min_samples_split=5;, score=0.900 total time=   1.8s
# [CV 4/5] END .max_depth=20, min_samples_split=5;, score=0.918 total time=   1.8s
# [CV 5/5] END .max_depth=20, min_samples_split=5;, score=0.894 total time=   1.7s
# [CV 1/5] END max_depth=20, min_samples_split=10;, score=0.888 total time=   1.7s
# [CV 2/5] END max_depth=20, min_samples_split=10;, score=0.877 total time=   1.7s
# [CV 3/5] END max_depth=20, min_samples_split=10;, score=0.895 total time=   1.9s
# [CV 4/5] END max_depth=20, min_samples_split=10;, score=0.915 total time=   1.9s
# [CV 5/5] END max_depth=20, min_samples_split=10;, score=0.891 total time=   1.8s
# [CV 1/5] END max_depth=20, min_samples_split=20;, score=0.885 total time=   1.8s
# [CV 2/5] END max_depth=20, min_samples_split=20;, score=0.872 total time=   1.8s
# [CV 3/5] END max_depth=20, min_samples_split=20;, score=0.895 total time=   1.8s
# [CV 4/5] END max_depth=20, min_samples_split=20;, score=0.916 total time=   1.8s
# [CV 5/5] END max_depth=20, min_samples_split=20;, score=0.887 total time=   1.7s

# %%
# Making inferences with the tuned model
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 20, 'min_samples_split': 5}
# 0.8960556764348453

# %%
# Calculating classification report
predictions = grid.predict(X_test_scaled2)

from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names = ["Confirmed", "False Positive", "Candidate"]))
# Out:
#                 precision    recall  f1-score   support
#
#      Confirmed       0.79      0.69      0.74       411
# False Positive       0.78      0.82      0.80       455
#      Candidate       0.96      0.99      0.98       882
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.84      0.84      1748
#   weighted avg       0.88      0.88      0.88      1748

# %%
# Saving the model
import joblib

filename = 'random_forest_model.sav'
joblib.dump(model, filename)
# Out:
# ['random_forest_model.sav']
